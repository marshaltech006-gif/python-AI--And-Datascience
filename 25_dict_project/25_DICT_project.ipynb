# %% [markdown]
# **Dictionary**
# --------------------

# %% [markdown]
# Dictionary is a mutable data type in Python.
# A python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed in curly braces {}.
# Keys must be unique in a dictionary, duplicate values are allowed.

# %% [markdown]
# ![image.png](attachment:a2e96a6a-77b7-4bbd-a0ab-336b23267551.png)

# %%
mydict = dict() # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {} # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {1:'one' , 2:'two' , 3:'three'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = dict({1:'one' , 2:'two' , 3:'three'}) # Create dictionary using dict()
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {'A':'one' , 'B':'two' , 'C':'three'} # dictionary with character keys
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = {1:'one' , 'A':'two' , 3:'three'} # dictionary with mixed keys
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys() # Return Dictionary Keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values()#Return Dictionary Values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items() # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria']}

# %%
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria'],'B':('Bat', 'cat', 'hat')}

# %%
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['asif', 'john', 'Maria'],
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'c': None, 'd': None, 'a': None, 'b': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value = 10
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence of key and value 
mydict3
# Out:
# {'c': 10, 'd': 10, 'a': 10, 'b': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = [10,20,30]
mydict3 = dict.fromkeys(keys , value) # Create a dictionary from a sequence ofkey and value 
mydict3
# Out:
# {'c': [10, 20, 30], 'd': [10, 20, 30], 'a': [10, 20, 30], 'b': [10, 20, 30]}

# %%
value.append(40) 
mydict3
# Out:
# {'c': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40]}

# %% [markdown]
# **Accessing Item**
# ------------------------

# %%
mydict = {1:'one' , 2:'two' , 3:'three' , 4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(1)
# Out:
# 'one'

# %%
mydict1 = {'Name':'Asif' , 'ID': 74123 , 'DOB': 1991 , 'job' :'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict1.get('Name')# inside get we need to pass key to get the value
# Out:
# 'Asif'

# %%
mydict1.get('job')
# Out:
# 'Analyst'

# %% [markdown]
# **Add ,Remove & Change**
# ---------------------------

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB'] = 1992 # Changing Dictionary Items
mydict1['Address'] = 'Delhi'
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1={'DOB': 1995}
mydict1.update(dict1)

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['job']='Analyst' ## this will help to add the  new KEy and value

# %%
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1995,
#  'Address': 'Delhi',
#  'job': 'Analyst'}

# %%
mydict1.popitem() # this help  us to delete the random item in the Dict
# Out:
# ('job', 'Analyst')

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
del[mydict1['ID']]# this logic will delete the respect key and value (the key which you defined )

# %%
mydict1
# Out:
# {'Name': 'Asif', 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.clear()

# %%
mydict1
# Out:
# {}

# %%
del mydict1 # this will del whole dict

# %%
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# **Copy Dictionary**
# -------------------------

# %%
mydict = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1=mydict#Id will be so if we do any changes in value it will impacat both

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict) , id(mydict1) # The address of both mydict & mydict1 will be the same
# Out:
# (2162765237888, 2162765237888)

# %%
mydict2 = mydict.copy() # Create a copy of the dictionary

# %%
mydict2
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict2)# id will be different if we copy means create a copy of dictionary
# Out:
# 2162765484032

# %%
mydict['Address']='Delhi'#this change will impact mydict1 as well because mydict=mydict1

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Delhi'}

# %%
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Delhi'}

# %%
mydict2## copy element wont imapact if any change made in original dictiona
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# **Loop through a Dictionary**
# ----------------------------------

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Delhi'}

# %%
del[mydict1['Address']]

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991}

# %%
mydict1['Job']='Analyst'

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
del mydict1

# %%
mydict1={'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Delhi','Job': 'Analyst'}

# %%
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
for i in mydict1:
    print(i,':',mydict1[i])# key & value
# Out:
# Name : Asif
# ID : 12345
# DOB : 1991
# Address : Delhi
# Job : Analyst

# %%
for i in mydict1:
    print(mydict1[i]) # Dictionary items
# Out:
# Asif
# 12345
# 1991
# Delhi
# Analyst

# %%
for i in mydict1:
    print(i) # this will return only key
# Out:
# Name
# ID
# DOB
# Address
# Job

# %% [markdown]
# **Dictionary Membership**
# ------------------------------

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1
# Out:
# True

# %%
'Asif' in mydict1# this is false because we check with value (membership test only done for key)
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
# **ALL & ANY**
# ----------------

# %% [markdown]
# **The all() method returns:
# True - If all all keys of the dictionary are true
# False - If any key of the dictionary is false
# The any() function returns True if any key of the dictionary is True. If not, any() returns False.**

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'} 
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1)
